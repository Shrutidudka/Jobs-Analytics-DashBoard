# %%
from selenium import webdriver
import time
import pandas as pd
import os
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import numpy as np
import random

linkedin_username = 'shruti.dudka10@gmail.com' #put your username here
linkedin_password = 'Shruti@10' #put your password here


driver = webdriver.Chrome(executable_path=r'C:\Users\Admin\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe')

driver.maximize_window()
linkedin = 'https://www.linkedin.com/jobs/collections/recommended/?currentJobId=3832806074&discover=recommended&discoveryOrigin=PUBLIC_COMMS'
driver.get(linkedin)

username = WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.ID, "username"))
)
password = driver.find_element(By.ID, "password")


username.send_keys(linkedin_username)
password.send_keys(linkedin_password)


driver.find_element(By.XPATH, '//*[@id="organic-div"]/form/div[3]/button').click()



WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.ID, "global-nav"))
)

dic={'designation':[],'comapany':[],'employeecount':[],'followers':[],'level':[],'totalapplicants':[],'location':[], 'industry':[]}
time.sleep(10)

list_of_page_numbers=driver.find_elements(By.CLASS_NAME,"artdeco-pagination__indicator.artdeco-pagination__indicator--number.ember-view")
for page in range(1,len(list_of_page_numbers)):
    page_numbers=driver.find_elements(By.CLASS_NAME,"artdeco-pagination__indicator.artdeco-pagination__indicator--number.ember-view")
    page_numbers[page].click()
    time.sleep(3)
    t=driver.find_elements(By.CLASS_NAME,"display-flex.job-card-container.relative.job-card-list.job-card-container--clickable")
    #driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    for r in range(len(t)):
        q=driver.find_elements(By.CLASS_NAME,"display-flex.job-card-container.relative.job-card-list.job-card-container--clickable")
        j=q[r].click()
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)
        
        
        try: #designation 
            degignation=driver.find_element(By.CLASS_NAME,"t-24.t-bold.inline").text
        except:
            degignation="NA"
        try: #company name
            comp_name=driver.find_element(By.CLASS_NAME,'ember-view.link-without-visited-state.inline-block.t-black').text
        except:
            comp_name="NA"
        try: #total employees
            total_employee=driver.find_element(By.CLASS_NAME,'jobs-company__inline-information').text
        except:
            total_employee="NA"
        try: #follower
            follower_of_company=driver.find_element(By.CLASS_NAME,'artdeco-entity-lockup__subtitle.ember-view.t-16').text
        except:
            follower_of_company="NA"
        try:
            level_of_job=driver.find_element(By.CLASS_NAME,"job-details-jobs-unified-top-card__job-insight-view-model-secondary").text
        except:
            level_of_job="NA"
        try: #no of applicants
            no_of_applicants=driver.find_element(By.CLASS_NAME,"t-black--light.mt2").text
        except:
            no_of_applicants="NA"
        try:  #location of work
            location_of_work=driver.find_element(By.CLASS_NAME,"t-black--light.mt2").find_element(By.TAG_NAME,"span").text
        except: 
            location_of_work="NA"
        try: # 
            industry= driver.find_element(By.CLASS_NAME,'t-14.mt5').text
        except:
            industry ="NA"
    
        dic['designation'].append(degignation)
        dic['comapany'].append(comp_name)
        dic['employeecount'].append(total_employee)
        dic['followers'].append(follower_of_company)
        dic['level'].append(level_of_job)
        dic["totalapplicants"].append(no_of_applicants)
        dic["location"].append(location_of_work)
        dic['industry'].append(industry)
    
    #time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12384\1639756323.py in <module>
#      46 for page in range(1,len(list_of_page_numbers)):
#      47     page_numbers=driver.find_elements(By.CLASS_NAME,"artdeco-pagination__indicator.artdeco-pagination__indicator--number.ember-view")
# ---> 48     page_numbers[page].click()
#      49     time.sleep(3)
#      50     t=driver.find_elements(By.CLASS_NAME,"display-flex.job-card-container.relative.job-card-list.job-card-container--clickable")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=126.0.6478.61)

# %%
scar = pd.DataFrame(dic)

# %%
scar
# Out:
#                                        designation  \
# 0                              Data Analyst Intern
# 1                                     Data Analyst
# 2             Data Analyst Trainee // Fresh Batch_
# 3                              Junior Data Analyst
# 4              Python Developer (Fresher Graduate)
# 5                            Data Analytics Intern
# 6              Database Engineer, Cloud SQL Server
# 7                                   Data Scientist
# 8                        Machine Learning Engineer
# 9                         Data or Business Analyst
# 10                            SQL Business Analyst
# 11                                    Data Analyst
# 12                                    Data Analyst
# 13                                Python Developer
# 14                                  Data Scientist
# 15  Senior Technology Manager – GRC & Applications
# 16                               PYTHON DEVELOPERS
# 17                           Data Analytics Intern
# 18                                    Data Analyst
# 19                                Python Developer
# 20                                Python Developer
# 21                                   Data Engineer
# 22                                Business Analyst
# 23         Junior Database Administrator (Fresher)
# 24                              Solution Architect
# 25        Business Development Lead Advance Market
# 26                           Data Analytics Intern
# 27                                  Data Scientist
# 28                             Full Stack Engineer
# 29             Data and Analytics Support Engineer
# 30                                         Analyst
# 31         AI Data Scientist, AI Safety Protection
# 32                             Engineering Analyst
# 33                                  Data Scientist
# 34                                         Analyst
# 35                                  Data Analyst 1
# 36                                   Data Engineer
# 37                       Site Reliability Engineer
# 38                                   Data Engineer
# 39                                  Data Analyst 2
# 40                                    Data Analyst
# 41                                    Data Analyst
# 42                                   Data Engineer
# 43                            Data Engineer Intern
# 44                            Salesforce Architect
# 45                         Associate Data Engineer
# 46                         Healthcare Data Analyst
# 47                                  Data Scientist
# 48                                Python Developer
# 49                                  Data Scientist
# 50                                  Data Scientist
# 51                                  Data Scientist
# 52                             Team Lead Treasures
# 53                          Implementation Manager
# 54                                  Data Scientist
# 55                        Trainee Business Analyst
# 56                                Business Analyst
# 57                          Junior, Data Scientist
# 58                                PYTHON DEVELOPER
#
#                                comapany           employeecount  \
# 0                        Unified Mentor        51-200 employees
# 1                      Lotus Interworks       201-500 employees
# 2                                               11-50 employees
# 3                       ConsultBae Jobs        51-200 employees
# 4                Clinchfactor Solutions        51-200 employees
# 5                        Unified Mentor        51-200 employees
# 6                                Google       10,001+ employees
# 7           Jio Platforms Limited (JPL)        51-200 employees
# 8                                 Groww     501-1,000 employees
# 9                         AKS ProTalent         11-50 employees
# 10            Tata Consultancy Services       10,001+ employees
# 11                               PayPal       10,001+ employees
# 12                Crescent Techservices        51-200 employees
# 13            Tata Consultancy Services       10,001+ employees
# 14
# 15
# 16                                   NA                      NA
# 17                       Unified Mentor        51-200 employees
# 18                                            10,001+ employees
# 19                              Soul AI         11-50 employees
# 20            Tata Consultancy Services       10,001+ employees
# 21            Tata Consultancy Services       10,001+ employees
# 22                       Northern Trust       10,001+ employees
# 23                      ConsultBae Jobs        51-200 employees
# 24                         Ather Energy   1,001-5,000 employees
# 25                     Biocon Biologics  5,001-10,000 employees
# 26                       Unified Mentor        51-200 employees
# 27                Sunrise Systems, Inc.     501-1,000 employees
# 28                                Apica        51-200 employees
# 29                            Norstella   1,001-5,000 employees
# 30                            Wishup.co       201-500 employees
# 31                               Google       10,001+ employees
# 32                               Google       10,001+ employees
# 33   LSEG (London Stock Exchange Group)       10,001+ employees
# 34                               dentsu       10,001+ employees
# 35                        Epsilon India   1,001-5,000 employees
# 36                    Rojgar Connection        51-200 employees
# 37                               5paisa     501-1,000 employees
# 38                      sliQue Robotics         11-50 employees
# 39  myGwork - LGBTQ+ Business Community         11-50 employees
# 40                         Fresh Prints       201-500 employees
# 41                                Masai       201-500 employees
# 42            Tata Consultancy Services       10,001+ employees
# 43                                            201-500 employees
# 44                      Wissen Infotech  5,001-10,000 employees
# 45                        Tech Mahindra       10,001+ employees
# 46                              Infosys       10,001+ employees
# 47  myGwork - LGBTQ+ Business Community         11-50 employees
# 48            Tata Consultancy Services       10,001+ employees
# 49                                  Jio       10,001+ employees
# 50            Travel Centric Technology        51-200 employees
# 51                 Digimoksha Solutions         11-50 employees
# 52                             DBS Bank       10,001+ employees
# 53                   Xoxoday (by Giift)       201-500 employees
# 54                               redBus     501-1,000 employees
# 55                    Just Energy India       201-500 employees
# 56                      ConsultBae Jobs        51-200 employees
# 57           Hudson's Bay Company India   1,001-5,000 employees
# 58                                   NA                      NA
#
#                followers                                              level  \
# 0       42,052 followers                                         Internship
# 1      231,135 followers  Full-time\nMatches your job preferences, job t...
# 2        7,782 followers                                             Remote
# 3       85,452 followers  Full-time\nMatches your job preferences, job t...
# 4        7,255 followers                                             Remote
# 5       42,052 followers                                         Internship
# 6   33,255,116 followers  Full-time\nMatches your job preferences, job t...
# 7      122,837 followers  Full-time\nMatches your job preferences, job t...
# 8      481,845 followers  Full-time\nMatches your job preferences, job t...
# 9      467,274 followers  Full-time\nMatches your job preferences, job t...
# 10  15,234,318 followers  Full-time\nMatches your job preferences, job t...
# 11   1,381,514 followers                                                 NA
# 12      24,714 followers  Full-time\nMatches your job preferences, job t...
# 13  15,234,319 followers  Full-time\nMatches your job preferences, job t...
# 14                                                                       NA
# 15                        Full-time\nMatches your job preferences, job t...
# 16                    NA  Full-time\nMatches your job preferences, job t...
# 17      42,052 followers                                         Internship
# 18   1,381,514 followers                                                 NA
# 19       8,091 followers                                          Part-time
# 20  15,234,319 followers  Full-time\nMatches your job preferences, job t...
# 21  15,234,319 followers  Full-time\nMatches your job preferences, job t...
# 22     475,716 followers  Full-time\nMatches your job preferences, job t...
# 23      85,461 followers  Full-time\nMatches your job preferences, job t...
# 24     465,857 followers  Full-time\nMatches your job preferences, job t...
# 25     409,598 followers  Full-time\nMatches your job preferences, job t...
# 26      42,052 followers                                         Internship
# 27     107,753 followers                                           Contract
# 28      11,194 followers  Full-time\nMatches your job preferences, job t...
# 29      34,558 followers  Full-time\nMatches your job preferences, job t...
# 30      95,561 followers  Full-time\nMatches your job preferences, job t...
# 31  33,255,124 followers  Full-time\nMatches your job preferences, job t...
# 32  33,255,124 followers  Full-time\nMatches your job preferences, job t...
# 33     382,005 followers  Full-time\nMatches your job preferences, job t...
# 34   1,294,120 followers  Full-time\nMatches your job preferences, job t...
# 35     397,433 followers  Full-time\nMatches your job preferences, job t...
# 36         219 followers                                   Mid-Senior level
# 37      49,172 followers  Full-time\nMatches your job preferences, job t...
# 53        Bengaluru, Karnataka, India
# 54        Bengaluru, Karnataka, India
# 55        Bengaluru, Karnataka, India
# 56                              India
# 57        Bengaluru, Karnataka, India
# 58        Bengaluru, Karnataka, India
#
#                                              industry
# 0   E-Learning Providers 51-200 employees 322 on L...
# 1   Software Development 201-500 employees 261 on ...
# 2   Technology, Information and Internet 11-50 emp...
# 3   IT Services and IT Consulting 51-200 employees...
# 4   Technology, Information and Internet 51-200 em...
# 5   E-Learning Providers 51-200 employees 322 on L...
# 6   Software Development 10,001+ employees 286,674...
# 7   Technology, Information and Internet 51-200 em...
# 8   Financial Services 501-1,000 employees 1,911 o...
# 9   Human Resources Services 11-50 employees 101 o...
# 10  IT Services and IT Consulting 10,001+ employee...
# 11  Software Development 10,001+ employees 30,604 ...
# 12  IT Services and IT Consulting 51-200 employees...
# 13  IT Services and IT Consulting 10,001+ employee...
# 14  Machinery Manufacturing 10,001+ employees 52,4...
# 15  Food and Beverage Services 1,001-5,000 employe...
# 16                                                 NA
# 17  E-Learning Providers 51-200 employees 322 on L...
# 18  Software Development 10,001+ employees 30,604 ...
# 19  Software Development 11-50 employees 177 on Li...
# 20  IT Services and IT Consulting 10,001+ employee...
# 21  IT Services and IT Consulting 10,001+ employee...
# 22  Financial Services 10,001+ employees 27,613 on...
# 23  IT Services and IT Consulting 51-200 employees...
# 24  Motor Vehicle Manufacturing 1,001-5,000 employ...
# 25  Biotechnology Research 5,001-10,000 employees ...
# 26  E-Learning Providers 51-200 employees 322 on L...
# 27  IT Services and IT Consulting 501-1,000 employ...
# 28  Software Development 51-200 employees 66 on Li...
# 29  Information Services 1,001-5,000 employees 407...
# 30  Business Consulting and Services 201-500 emplo...
# 31  Software Development 10,001+ employees 286,674...
# 32  Software Development 10,001+ employees 286,674...
# 33  Financial Services 10,001+ employees 20,399 on...
# 34  Advertising Services 10,001+ employees 15,034 ...
# 35  Advertising Services 1,001-5,000 employees 1,3...
# 36  Staffing and Recruiting 51-200 employees 6 on ...
# 37  Financial Services 501-1,000 employees 765 on ...
# 38  Software Development 11-50 employees 8 on Link...
# 39  Technology, Information and Internet 11-50 emp...
# 40  Retail Apparel and Fashion 201-500 employees 1...
# 41  Higher Education 201-500 employees 704 on Link...
# 42  IT Services and IT Consulting 10,001+ employee...
# 43  Financial Services 201-500 employees 523 on Li...
# 44  IT Services and IT Consulting 5,001-10,000 emp...
# 45  IT Services and IT Consulting 10,001+ employee...
# 46  IT Services and IT Consulting 10,001+ employee...
# 47  Technology, Information and Internet 11-50 emp...
# 48  IT Services and IT Consulting 10,001+ employee...
# 49  Telecommunications 10,001+ employees 65,823 on...
# 50  IT Services and IT Consulting 51-200 employees...
# 51  IT Services and IT Consulting 11-50 employees ...
# 52       Banking 10,001+ employees 34,539 on LinkedIn
# 53  Software Development 201-500 employees 473 on ...
# 54  Technology, Information and Internet 501-1,000...
# 55  Services for Renewable Energy 201-500 employee...
# 56  IT Services and IT Consulting 51-200 employees...
# 57        Retail 1,001-5,000 employees 65 on LinkedIn
# 58                                                 NA

# %%
scar = scar.to_csv('scar.csv',index=False)
